# %%
# source: https://howtofix.io/scraping-all-reviews-of-a-movie-from-rotten-tomato-using-soup-id39891
import pandas as pd
import requests
import re
import time
session = requests.Session()

# %%
def get_reviews(movie_id, 
                reviewer = 'user', 
                scraping_limit = 10
    ):
    '''
    Scrapes rotten tomatoes for reviews and related info

    args: 
        movie_id = the title of the movie, 
        reviewer = select reviewer pool from list: ['critic', 'user']. Default is user. 
        scrape_limit = number of pages to stop scraping. Default is 10. 

    returns: 
        a pandas dataframe of reviewer data 
    '''

    url = f'https://www.rottentomatoes.com/m/{movie_id}/reviews'
    r = requests.get(url)
    movie_id = re.findall(r'(?<=movieId":")(.*)(?=","type)',r.text)[0]

    if reviewer == 'critic':
        api_url = f"https://www.rottentomatoes.com/napi/movie/{movie_id}/criticsReviews/all"
    if reviewer == 'user':
        api_url = f"https://www.rottentomatoes.com/napi/movie/{movie_id}/reviews/user"
    payload = {
        'direction': 'next',
        'endCursor': '',
        'startCursor': '',
    }

    pages_scraped = 0
    scraping_limit = scraping_limit
    review_data = []
    while True:
        r = session.get(api_url, 
                  params=payload)
        data = r.json()

        if not data['pageInfo']['hasNextPage']:
            print('scaping completed')
            break
        elif pages_scraped == scraping_limit:
            print('scraping limit reached')
            break

        payload['endCursor'] = data['pageInfo']['endCursor']
        payload['startCursor'] = data['pageInfo']['startCursor'] if data['pageInfo'].get('startCursor') else ''

        review_data.extend(data['reviews'])
        time.sleep(.1)
        pages_scraped += 1
        print(f'pages scraped: {pages_scraped}')
#         print(f'len of df: {len(review_data)}')

    return review_data

# %%
movie_id = 'the_matrix_resurrections'

data = get_reviews(movie_id , 
                   scraping_limit = 2)
df = pd.json_normalize(data)
print(len(df))
df.head()
# Out:
# pages scraped: 1
# pages scraped: 2
# scraping limit reached
# 20
#    rating                                             review  isVerified  \
# 0     5.0  Superb, loved it. Great cast, pacing, action, ...       False
# 1     3.5  )\nIt's a fun, nostalgic, meta movie that is e...       False
# 2     3.0  It's hard to put a finger on what's wrong with...       False
# 3     2.0  The Matrix Awakens.\n\nDidn't hate it. Also gl...       False
# 4     2.5  Well, well, well.  So you've come to read a re...       False
#
#    isSuperReviewer  hasSpoilers  hasProfanity  score timeFromCreation  \
# 0            False        False         False    5.0           2h ago
# 1            False        False         False    3.5           2h ago
# 2            False        False         False    3.0           2h ago
# 3            False        False         False    2.0           2h ago
# 4            False        False          True    2.5           2h ago
#
#   user.realm                           user.userId displayName  \
# 0   Flixster  c297075d-7272-426e-96f2-baab5631bc5e         NaN
# 1         RT                             979423830     Ricky L
# 2         RT                             823783380      Mela N
# 3   Fandango  50c0c39c-c3d5-486f-8c96-59e40991101c      Eric H
# 4         RT                             979147760      R.J. E
#
#   user.displayName    user.accountLink  \
# 0              NaN                 NaN
# 1          Ricky L  /user/id/979423830
# 2           Mela N  /user/id/823783380
# 3           Eric H                 NaN
# 4           R.J. E  /user/id/979147760
#
#                                      displayImageUrl
# 0                                                NaN
# 1                                                NaN
# 2  https://graph.facebook.com/v3.3/1169751812/pic...
# 3                                                NaN
# 4                                                NaN

# %%
movie_id = 'avengers_endgame'

data = get_reviews(movie_id,
                   scraping_limit = 3
                  )
df2 = pd.json_normalize(data)
print(len(df2))
df2.head()
# Out:
# pages scraped: 1
# pages scraped: 2
# pages scraped: 3
# scraping limit reached
# 30
#    rating                                             review  \
# 0     5.0  Honestly, an epic movie, for fans and the gene...
# 1     5.0  Filme incrível, cativante, emocionante e histó...
# 2     5.0  Filme emocionante, com tons cômicos,envolvente...
# 3     5.0  I love this movie, it is so captivating and sc...
# 4     5.0  An incredible ending to an incredible franchis...
#
#          displayName                                    displayImageUrl  \
# 0          Gabriel A  https://graph.facebook.com/v3.3/11352663306121...
# 1          Marcela A  https://graph.facebook.com/v3.3/96402369786835...
# 2            Bruno S  https://graph.facebook.com/v3.3/46581044708929...
# 3  Marcos Bismarck d                                                NaN
# 4           Ciaran W                                                NaN
#
#    isVerified  isSuperReviewer  hasSpoilers  hasProfanity  score  \
# 0       False            False        False         False    5.0
# 1       False            False        False         False    5.0
# 2       False            False        False         False    5.0
# 3       False            False        False         False    5.0
# 4       False            False        False         False    5.0
#
#   timeFromCreation   user.displayName    user.accountLink user.realm  \
# 0           2h ago          Gabriel A  /user/id/979421365         RT
# 1           3h ago          Marcela A  /user/id/979423722         RT
# 2          10h ago            Bruno S  /user/id/979423056         RT
# 3          10h ago  Marcos Bismarck d  /user/id/979423040         RT
# 4          18h ago           Ciaran W  /user/id/979422608         RT
#
#   user.userId
# 0   979421365
# 1   979423722
# 2   979423056
# 3   979423040
# 4   979422608

# %%
df2['review'].values[-1]
# Out:
# 'This is my 2nd favorite marvel movie had great scenes tons of action comedy and hope and man the ending was just great.'
